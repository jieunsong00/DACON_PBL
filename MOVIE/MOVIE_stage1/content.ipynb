# %%
#hiddencell
from pbl_tools import *

# %% [markdown]
# # 영화 관객 수 예측 프로젝트
#
# ![movie_inner](https://user-images.githubusercontent.com/75363345/220539870-23221483-209a-4f46-b468-3561ae9b95cd.png)
#
# # 1. 소개
#
# 쇼핑몰을 걷다가 강렬한 팝콘 냄새에 이끌린 적 있으신가요?
# 냄새를 따라가다 보면 새로운 세계가 펼쳐지는 장소에 도착하게 되죠!
#
# 그렇습니다, 바로 영화관입니다.
# 영화관에선 그야말로 오감으로 이야기를 느낄 수 있는데요!
#
#
# 그럼 관객들에게 바로 그 이야기를 선보이는 입장은 어떨까요?
# 시간과 노력을 쏟은 모두가 영화의 성공을 바라며 떨리는 마음으로 개봉을 기다리겠죠?
#
# ‘일이 잘되고 못되는 것은 하늘에 달린 것’이라는 말도 있지만,
# 만약 영화를 상영관에 올리기 전. 아니, 만들기도 전에 흥행 여부를 점칠 수 있다면 어떨까요?
#
# # 2. 목적
#
# 이번 프로젝트에선 회귀 모델을 사용해 영화의 관객 수를 예측해 볼 것입니다.
# 이 과정에서 데이터를 이해하고, 분석 목표에 따라 처리하는 과정을 배워 나갈 수 있습니다.
# 차근차근 프로젝트를 진행하다 보면, 데이콘의 문제 기반 학습에도 점차 익숙해질 거예요!
#
# # 스테이지 1

# %% [markdown]
# # 1. 데이터 분석을 위한 pandas 라이브러리(Library) import
# [문제 1]
# pandas 라이브러리(Library)를 import 하기 위해서 아래 빈칸을 채워 주세요.
# pandas는 자주 사용하는 라이브러리(Library)이므로 축약어인 pd로 불러와 주세요.

# %%
import ___ as pd

# %%
#checkcode
def check(user_answer_pandas=pd):
    if hasattr(user_answer_pandas, 'read_csv'):
        return True
    else:
        return False
check()
# Out:
# True

# %% [markdown]
# ### Inst.
# `import pandas as pd`는 Python에서 **pandas 라이브러리(library)를 import** 하는 코드입니다.
# pandas는 데이터 분석과 관련된 다양한 기능을 제공하며,
# 표 형식의 데이터를 다루는 데 특화되어 있습니다.
#
# 코드를 사용하기 위해서는 먼저 Python 환경에서 pandas 라이브러리를 설치해야 합니다.
# 설치가 완료되면, Python 스크립트나 Jupyter Notebook 등에서 `import pandas as pd` 코드를 작성하면 됩니다.
# 이렇게 작성하면 pandas 라이브러리(library)에서 제공하는 다양한 **함수와 클래스**를 사용할 수 있습니다.
#
# 이 코드는 "모듈 불러오기"라는 기법 중 하나입니다.
# Python에서 모듈은 함수, 클래스, 변수 등을 정의하고 있는 파일을 의미합니다.
# `import pandas`는 pandas 모듈을 불러오는 것이며,
# `as pd`는 pandas 모듈을 pd라는 이름으로 사용하겠다는 의미입니다.
# 이렇게 하면 코드 작성 시 pandas 함수나 클래스를 `pd.` 접두사를 붙여서 사용할 수 있습니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# import pandas as pd
# ```

# %% [markdown]
# # 2.train.csv 파일을 pandas를 이용해 데이터프레임으로 읽어오기
#
# [문제 2]
# train.csv 파일을 데이터프레임(DataFrame)으로 읽어오기 위해 `read_csv()` 함수를 사용해 보세요.

# %%
train = pd.___('train.csv')
train
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
#checkcode
ensure_vals(globals(), 'train')
@check_safety
def check(user_answer_train=train):
    c_point0 = hasattr(user_answer_train, 'tail')

    if c_point0 :
        return True
    else:
        return False

check()

# %% [markdown]
# ### Inst.
# 이번 프로젝트에서는 총 **3가지 데이터**가 존재하며, 모두 `.csv` 파일 형식으로 제공됩니다.
#
# - train.csv: 모델을 학습하기 위해 사용하는 데이터
# - test.csv: 모델을 통해 정답을 예측하기 위해 사용하는 데이터
# - sample_submission.csv: 예측한 정답 값을 기록하여 제출하기 위한 샘플 정답 파일
#
# 위에서 호출한 pandas 라이브러리(Library)를 사용하여 train.csv 파일을 읽어오겠습니다.
# pandas 라이브러리의 **`read_csv('파일경로/파일명.csv')`** 함수는
# train.csv 파일을 읽어와 **데이터프레임(DataFrame) 형태로 train 변수에 저장**하는 코드입니다.
#
# 이때, 데이터프레임은 pandas 라이브러리(Library)에서 제공하는 표 형태의 데이터 구조입니다.
# 데이터프레임은 행(row)과 열(column)로 이루어져 있으며,
# 각 열(column)은 서로 다른 데이터 타입을 가질 수 있습니다.
#
# 코드를 사용하기 위해서는 `train.csv` 파일이 먼저 준비되어 있어야 하며,
# `train.csv` 파일이 저장된 경로를 정확하게 입력해야 합니다.
# `read_csv()` 함수를 사용하여 파일을 데이터프레임으로 읽어온 후,
# 이를 통해 **데이터의 구조와 내용을 분석하고 모델링**을 수행할 수 있습니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# train = pd.read_csv('train.csv')
# train
# ```

# %% [markdown]
# # 3.test.csv, sample_submission.csv 파일을 pandas를 이용해 데이터프레임으로 읽어오기
# [문제 3]
# train 데이터를 읽어왔으므로, 이제 pandas를 사용하여 test.csv와 sample_submission.csv 파일을
# 각각 test와 submission이라는 이름의 데이터프레임(DataFrama)으로 불러와 봅시다.
# 아래 빈칸을 채워주세요.

# %%
test = pd.___('test.csv')
submission = pd.___('sample_submission.csv')

# %%
#checkcode
ensure_vals(globals(), 'test', 'submission')
@check_safety
def check(user_answer_test=test, 
          user_answer_submission=submission):
    
    c_point0 = hasattr(user_answer_test, 'tail')
    c_point1 = hasattr(user_answer_submission, 'head')

    if c_point0 and c_point1:
        return True
    else:
        return False

check()
# Out:
# True

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
#
# `read_csv()` 를 활용하여 파일을 읽어와보세요.

# %% [markdown]
# ### Solution.
# ```python
# test = pd.read_csv('test.csv')
# submission = pd.read_csv('sample_submission.csv')
# ```

# %% [markdown]
# # 4.데이터프레임(DataFrame)의 상위 5개 행(row) 데이터 출력하기
# [문제 4]
# pandas의 `head()` 메소드를 이용하여 상위 5개의 행(row) 데이터를 출력해 보세요.

# %%
submission.___()
# Out:
#          title  box_off_num
# 0       용서는 없다            0
# 1  아빠가 여자를 좋아해            0
# 2          하모니            0
# 3          의형제            0
# 4        평행 이론            0

# %%
#checkcode
ensure_vals(globals())
@check_safety
def check(user_answer = _, number = 5):
    c_point0 = (len(user_answer) == number)
    if c_point0:
        return True
    else:
        return False
check()

# %% [markdown]
# ### Inst.
# 해당 코드는 pandas 라이브러리(Library)를 사용하여 생성된 데이터프레임(DataFrame)에서 **상위 5개의 행(row)** 을 출력하는 코드입니다.
# submission 변수에 저장된 데이터프레임에서 상위 5개의 행을 출력하는 코드로, 데이터를 확인하고 분석할 때 사용됩니다.
#
# 이 코드 기법은 pandas 라이브러리에서 제공하는 데이터프레임의 메소드 중 하나입니다.
# `head(n)` 메소드는 기본적으로 상위 5개의 행(row)을 출력하며, 인자로 전달된 n에 따라 **상위 n개의 행(row)** 을 출력할 수 있습니다.
# **데이터프레임의 구조와 값을 빠르게 확인**할 수 있는 간편한 기능입니다.
# 확인하고 싶은 행의 개수를 2개로 변경하고 싶다면 `head(2)`로 입력해 보세요
#
# ----
#
# #### 결과 해석
#
# 제출할 submission 데이터는 **title과 box_off_num** 칼럼(column)으로 이루어져 있습니다.
# 그러나 모든 box_off_num 데이터가 0으로 이루어져 있기 때문에,
# 이번 프로젝트에서는 **각 title에 따른 영화 관객 수를 예측하는 문제** 임을 알 수 있습니다.
# 따라서, 예측한 영화 관객 수로 box_off_num의 값을 모두 채우면 됩니다.
#
# 이를 위해 모델링을 통해 각 title에 따른 영화 관객 수를 예측하고,
# 이를 box_off_num 칼럼에 대입하여 최종적인 submission 데이터를 생성합니다.
#
# **[sample_submission.csv]**
# - title: 영화별 고유 id
# - box_off_num: 영화 관객 수

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# submission.head()
# ```

# %% [markdown]
# # 5. 데이터프레임(DataFrame)을 CSV 파일로 저장하기

# %%
submission.to_csv('submission.csv', index=False)

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
# pandas 라이브러리(Library)를 사용하여 **데이터프레임(DataFrame)을** **csv 파일로 저장**하는 코드입니다.
# submission 데이터프레임을 생성하고, 저장할 csv 파일의 **이름과 경로**를 지정한 후, **`to_csv()`** 메소드를 사용하여 저장합니다.
#
# submission 데이터프레임을 **submission.csv 파일명** 으로 저장하며,
# **`index=False`** 옵션을 주어 **인덱스 정보를 제외** 하고 저장합니다.
#
# > 예시: submission.to_csv('저장할 csv 파일명', index=False)
#
# `to_csv()` 메소드는 데이터프레임을 csv 파일로 저장하는 기능을 수행합니다.
# 인자로 전달된 **파일명과 경로** 에 따라 csv 파일을 저장할 수 있으며,
# 인덱스(index) 정보를 포함할지 여부를 결정할 수 있습니다.
# 이는 데이터프레임의 **구조를 유지** 하면서 csv 파일로 데이터를 저장할 수 있는 효과적인 방법 중 하나입니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# empty
