# %%
#hiddencell
from pbl_tools import *

# %% [markdown]
# # 스테이지 8

# %% [markdown]
# # 1. pandas를 이용해 csv 파일 읽어오기
# [문제 1]
# 앞에서 배운 내용을 바탕으로 빈칸을 채워 train.csv, test.csv, sample_submission.csv 를 읽어와 봅시다.

# %%
import ___ as pd

train = pd.___('train.csv')
test = pd.___('test.csv')
submission = pd.___('sample_submission.csv')

# %%
#checkcode
ensure_vals(globals(), 'train', 'test', 'submission')
@check_safety
def check(
          user_answer_train=train,
          user_answer_test=test, 
          user_answer_submission=submission
          ):
    
    c_point0 = hasattr(user_answer_train, 'tail')
    c_point1 = hasattr(user_answer_test, 'tail')
    c_point2 = hasattr(user_answer_submission, 'tail')

    if c_point0 and c_point1 and c_point2 :
        return True
    else:
        return False

check()
# Out:
# True

# %% [markdown]
# ### Inst.
# csv 파일을 데이터프레임(DataFrame) 형태로 불러와 봅시다.
#
# train.csv, test.csv, sample_submission.csv를 각각
# train, test, submission 변수로 할당하여 불러와 보세요.

# %% [markdown]
# ### Hint.
# `pd.read_csv('파일경로/파일명')` 를 활용해 보세요!

# %% [markdown]
# ### Solution.
# ```python
# import pandas as pd
#
# train = pd.read_csv('train.csv')
# test = pd.read_csv('test.csv')
# submission = pd.read_csv('sample_submission.csv')
# ```

# %% [markdown]
# # 2. 결측치를 평균값으로 채운 train_fill 데이터셋 생성하기
# [문제 2]
# train 데이터셋에 있는 결측값을 평균값(mean)으로 채우고, 이를 train_fill_mean 변수에 저장해 보세요.
# 아래 빈칸을 채워 주세요.

# %%
train_mean = train['dir_prev_bfnum'].___()

train_fill = train.fillna(___)  
test_fill = test.fillna(___)
train_fill
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
#      dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0              0.00             0         91          2        23398
# 1        1161602.50             2        387          3      7072501
# 2         220775.25             4        343          4      6959083
# 3          23894.00             2         20          6       217866
# 4              1.00             1        251          2       483387
# ..              ...           ...        ...        ...          ...
# 595         3833.00             1        510          7      1475091
# 596       496061.00             1        286          6      1716438
# 597            0.00             0        123          4         2475
# 598            0.00             0        431          4      2192525
# 599            0.00             0        363          5      7166532
#
# [600 rows x 12 columns]

# %%
#checkcode
ensure_vals(globals(),'train_fill')
@check_safety
def check(user_answer=_):
    c_point0 = _.shape == (600,12)
    if c_point0:
        return True
    else:
        return False
check()
# Out:
# True

# %% [markdown]
# ### Inst.
#
# 모델링을 진행하기 전에, dir_prev_bfnum 피처(feature)에 있는 330개의 결측치를 처리해야 합니다.
#
# 이전 스테이지에서는 **결측값을 0으로 대체** 한 후 삭제하였습니다.
# 하지만 이번 스테이지에서는 **결측값을 평균값으로 대체** 한 후 train_fill 변수에 할당해보세요.
#
# 이를 통해 결측치 대체 과정을 수행할 수 있습니다.

# %% [markdown]
# ### Hint.
# `fillna()` 를 활용하여 결측치가 존재하는 행을 `dir_prev_bfnum` 피처의 평균값으로 채워보세요.

# %% [markdown]
# ### Solution.
# ```python
# train_mean = train['dir_prev_bfnum'].mean()
#
# train_fill = train.fillna(train_mean)
# test_fill = test.fillna(train_mean)
# train_fill
# ```

# %% [markdown]
# # 3. 영화 관객 수 모델 학습
#
# [문제 3]
# 모델링을 하기에 앞서, 종속변수와 독립변수를 설정해 주세요.
# 회귀모델을 정의하고 학습해 보세요.
# 아래 빈칸을 채워 주세요.

# %%
formula = """
___ ~ (___) + (___) + (___) + (___) + (___)
"""

___ statsmodels.api ___ sm

model = sm.OLS.from_formula(___, data = ___) # 모델 정의
model = model.___() # 모델 학습
___ = model.___(___) # 모델 예측

# %%
#checkcode
ensure_vals(globals(), 'model')
@check_safety
def check(user_answer=model):
    c_point0 = hasattr(user_answer, 'summary')

    if c_point0:
        return True
    else:
        return False

check()
# Out:
# True

# %% [markdown]
# ### Inst.
# 1. `~`(물결) 왼쪽에 종속변수를 넣어 주세요.
# 2. `~`(물결) 오른쪽에 독립변수를 넣어 주세요.

# %% [markdown]
# ### Hint.
# 1. `~`(물결) 왼쪽에 종속변수 `box_off_num`를 넣어 주세요.
# 2. `~`(물결) 오른쪽에 독립변수`time, dir_prev_bfnum, dir_prev_num, num_staff, num_actor`를 넣어 주세요.
#
# 3. sm은 `statsmodels.api` 의 약칭입니다. import 와 as 를 이용해서 `statsmodels.api`를 불러와 주세요.
#
# 4. `sm.OLS.from_formula` 인자에는 위에서 만든 formula와, 결측치를 0으로 대체한 데이터프레임(train_fill)를 이용해 모델을 정의해 주세요.
#
# 5. 1번에서 선언된 모델을 `fit()` 함수를 이용해 학습시켜 보세요.
#
# 6. `predict()` 함수를 이용해서 학습이 완료된 model을 가지고 test 데이터셋을 예측해 보세요. 예측된 결괏값을 predict 변수에 할당해 주세요.

# %% [markdown]
# ### Solution.
# ```python
# formula = """
# box_off_num ~ (time) + (dir_prev_bfnum) + (dir_prev_num) + (num_staff) + (num_actor)
# """
#
# import statsmodels.api as sm
# model = sm.OLS.from_formula(formula, data = train_fill)
# model = model.fit()
# predict = model.predict(test_fill)
# ```

# %% [markdown]
# # 4. 예측된 영화 관객 수를 submission 파일에 추가하기
# [문제 4]
# 예측된 영화 관객 수를 submission 데이터프레임(DataFrame)의 box_off_num 열(column)에 저장해 보세요.
# 아래 빈칸을 채워 주세요.

# %%
___['___'] = ___

submission.head()

# %%
#checkcode
ensure_vals(globals(),'submission')
@check_safety
def check(user_answer=submission):
    c_point0 = (user_answer['box_off_num'].loc[0] == predict[0])
    if c_point0:
        return True
    else:
        return False
check()

# %% [markdown]
# ### lnst.
#
# `submission['___']`은 submission 데이터프레임에서 특정 피처(feature)를 지칭하는 부분입니다.
# 해당 피처에 대한 값을 변경하려는 것을 나타냅니다.
#
# `=` 다음에 오는 대체할 값은 해당 피처에 새로운 값을 할당하는 부분입니다.
# 이 값으로 피처의 값을 대체하게 됩니다.

# %% [markdown]
# ### Hint.
#
# 데이터 셋['피처명'] = 채울 값

# %% [markdown]
# ### Solution.
# ```python
# submission['box_off_num'] = predict
# submission.head()
# ```

# %% [markdown]
# # 5. 데이터프레임(DataFrame)을 CSV 파일로 저장하기
# [문제 5]
# 파일을 제출하기 위해서는 저장을 해야 합니다.
# submission 데이터프레임을 `submission.csv`라는 파일로 저장해 보세요.
# 아래 빈칸을 채워주세요.

# %%
submission.___('submission.csv', index=False)

# %%
#checkcode
ensure_vals(globals(),'submission','test')
@check_safety
def check():
    check_submission = pd.read_csv('submission.csv')
    
    if len(check_submission) == len(test):
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.
# `to_csv()` 함수는 pandas 데이터프레임을 csv 파일로 저장하는 함수입니다.
#
# `index=False` 옵션은 인덱스를 저장하지 않도록 설정하는 것을 의미합니다.

# %% [markdown]
# ### Hint.
# `to_csv()` 함수를 사용해 보세요.

# %% [markdown]
# ### Solution.
# ```python
# submission.to_csv('submission.csv', index=False)
# ```
