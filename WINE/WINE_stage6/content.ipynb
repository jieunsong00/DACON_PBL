# %%
#hiddencell
# %pip install seaborn 

from pbl_tools import *

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import sklearn
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fe = fm.FontEntry(fname = 'NotoSansKR-Regular.otf', name = 'NotoSansKR')
fm.fontManager.ttflist.insert(0, fe)
plt.rc('font', family='NotoSansKR')

# %% [markdown]
# # 스테이지 6

# %% [markdown]
# # 1.pandas를 이용해 csv 파일 읽어오기
#
# [문제 1]
# Pandas 라이브러리(library)를 가져와보세요.
# 그리고 train.csv, test.csv, sample_submission.csv 파일을 각각 train, test, submission 변수로 읽어오세요.
# 아래 빈칸을 채워주세요.

# %%
import pandas as pd

train = ___('train.csv')
test = ___('test.csv')
submission = ___('sample_submission.csv')
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
#
#    density    pH  sulphates  alcohol   type
# 0  0.99432  3.44       0.44     10.2  white
# 1  0.99690  3.19       0.59      9.5    red
# 2  0.99176  3.05       0.52     10.9  white

# %%
#checkcode
ensure_vals(globals(), 'train', 'test', 'submission')
@check_safety
def check(user_answer_train=train,
          user_answer_test=test, 
          user_answer_submission=submission):
    
    c_point0 = hasattr(user_answer_train, 'tail')
    c_point1 = hasattr(user_answer_test, 'tail')
    c_point2 = hasattr(user_answer_submission, 'tail')

    if c_point0 and c_point1 and c_point2 :
        return True
    else:
        return False

check()

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# `pd.read_csv('')` 를 활용해보세요!

# %% [markdown]
# ### Solution.
# ```python
# import pandas as pd
#
# train = pd.read_csv('train.csv')
# test = pd.read_csv('test.csv')
# submission = pd.read_csv('sample_submission.csv')
# ```

# %% [markdown]
# # 2.train 데이터셋 One-hot encoding 적용
#
# [문제 2]
# 이번 스테이지에서는 get_dummies 함수와 더미 변수를 만드는 One-hot encoding 을 사용하여
# 범주형 변수를 처리해 보도록 하겠습니다.
#
# 1. `get_dummies` 함수를 사용하여 type 열을 원-핫 인코딩하여 새로운 열들로 변환해 주세요.
# 2. `concat` 함수를 사용하여 기존의 train 데이터프레임과 원-핫 인코딩된 열들을 수평 방향으로 합칩니다.
# 3. `drop` 함수를 사용하여 type 열을 제거합니다. 여기서 axis=1은 열 방향으로 제거하라는 의미입니다.
# 4. `rename` 함수를 사용하여 열 이름을 변경해 보세요.

# %%
train_dummies = pd.___(train['type'])
train = pd.___([train,train_dummies], axis=1)     
train = train.___(labels = 'type', axis = 1)            
train.___(columns = {0:'white', 1:'red'}, inplace = True)

# %%
#checkcode
ensure_vals(globals(), 'train')
@check_safety
def check(user_answer=train, number=(5497, 15)):

    c_point1 = user_answer.shape == number
    if c_point1:
        return True
    else:
        return False
    
check()
# Out:
# True

# %% [markdown]
# ### Inst.
#
# 1. `pd.get_dummies(train['type'])`를 사용하여 type 열을 원-핫 인코딩하여 새로운 열들로 변환합니다.
# 즉, type 열의 각 값에 대해 해당하는 열을 생성하고, 해당 값에 해당하는 열에는 1을, 나머지 열에는 0을 할당합니다.
# 이렇게 생성된 열들은 각각 white와 red를 나타내는 열로 가정합니다.
#
# 2. `pd.concat([train,train_gummies], axis=1)`를 사용하여
# 기존의 train 데이터프레임과 원-핫 인코딩된 열들을 수평 방향으로 합칩니다.
# 이를 통해 train 데이터프레임에 white와 red 열이 추가됩니다.
#
# 3. `train.drop(labels=type, axis=1)`을 사용하여 type 열을 제거합니다.
# 여기서 axis=1은 열 방향으로 제거하라는 의미입니다.
#
# 4. `train.rename(columns={0: white, 1: red}, inplace=True)`을 사용하여 열 이름을 변경합니다.
# 기존에 생성된 열들의 이름이 0과 1로 되어 있는데, 이를 white와 red로 변경합니다.
# rename 함수의 columns 매개변수에는 열 이름을 변경할 매핑을 딕셔너리 형태로 지정합니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# getgummies = pd.get_dummies(train['type'])
# train = pd.concat([train,getgummies], axis=1)
# train = train.drop(labels = 'type', axis = 1)
# train.rename(columns = {0:'white', 1:'red'}, inplace = True)
# ```

# %% [markdown]
# # 3.test 데이터 셋 One-hot encoding 적용
#
# [문제 3]
# 그럼 test 데이터에도 train 데이터 전처리 과정을 동일하게 적용해 주겠습니다.
#
# 1. type 열을 원-핫 인코딩하여 새로운 열들로 변환해 주세요. 변환된 데이터프레임은 test_dummies 변수에 할당해 주세요.
# 2. 기존의 test 데이터프레임과 원-핫 인코딩된 열들을 수평 방향으로 합쳐보세요.
# 3. 열 방향으로 type 열을 제거해 주세요.
# 4. 0은 white로, 1은 red로 열 이름을 변경해 보세요.

# %%
test_dummies = pd.___(test['type'])
test = pd.___([___,___], axis=___)       
test = test.___(labels = '___', axis = ___)          
test.___(columns = {___:'___', ___:'___'}, inplace = True)

# %%
#checkcode
ensure_vals(globals(), 'test')
@check_safety
def check(user_answer=test, number=(1000, 14)):

    c_point1 = user_answer.shape == number
    if c_point1:
        return True
    else:
        return False
    
check()
# Out:
# True

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# 1. get_dummies
# 2. concat
# 3. drop
# 4. rename

# %% [markdown]
# ### Solution.
# ```python
# test_dummies = pd.get_dummies(test['type'])
# test = pd.concat([test,test_dummies], axis=1)
# test = test.drop(labels = 'type', axis = 1)
# test.rename(columns = {0:'white', 1:'red'}, inplace = True)
# ```

# %% [markdown]
# # 4.Feature Selection : 종속변수 & 독립변수 설정
#
# [문제 4]
# 1. train 데이터프레임(DataFrame)의 열(column) 인덱스(index) 2부터 끝까지를 선택하여 features 변수에 저장해 보세요.
# 2. features에 저장된 열들을 선택하여 데이터프레임 X에 할당해 주세요.
# 3. 종속 변수를 객체 y에 할당해 주세요.

# %%
features = train.___[___:]

X = train[___]
y = train[___]

# %%
#checkcode
ensure_vals(globals(), 'X', 'y')
@check_safety
def check(
    user_x=X, 
    user_y=y,
    value=13,
    y_name='quality'
):
    
    c_point0 = len(user_x.columns) == value
    c_point1 = y_name == user_y.name
    
    if c_point0 and c_point1:
        return True
    else:
        return False

check()
# Out:
# True

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# 1. train.columns[...]
# 2. train['칼럼명']

# %% [markdown]
# ### Solution.
# ```python
# features = train.columns[2:]
#
# X = train[features]
# y = train['quality']
# ```

# %% [markdown]
# # 5.RandomForestClassifier의 최적 하이퍼파라미터 탐색 및 전체 데이터 학습
#
# 그럼 validation 셋 구축 없이 전체 X와 y를 이용하여 GridSearchCV를 사용해 보겠습니다.
#
# [문제 5]
# 1. RandomForestClassifier를 기반으로 하는 `GridSearchCV` 객체를 생성해 보세요.
# 2. param_grid에는 최적화할 파라미터 후보 값들을 담고 있는 파라미터를 전달해 보세요.
# 데이터를 나눌 배치의 개수는 2개로 설정해 주세요.
# 3. 전체 데이터셋 X,y 에 대해 학습시켜주세요.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

params = {'n_estimators' : [100, 150, 200],
          'criterion' : ['gini', 'entropy']}

rf_total = ___(___(random_state=42), param_grid=___, cv=___, return_train_score=True, verbose=3)

rf_total.fit(___,___)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# [CV] criterion=gini, n_estimators=100 ................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. criterion=gini, n_estimators=100, total=   1.0s
# [CV] criterion=gini, n_estimators=100 ................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV] ................. criterion=gini, n_estimators=100, total=   1.0s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] ................. criterion=gini, n_estimators=100, total=   1.0s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] ................. criterion=gini, n_estimators=100, total=   1.0s
# [CV] criterion=gini, n_estimators=150 ................................
# [CV] ................. criterion=gini, n_estimators=150, total=   1.5s
# ...

# %%
#checkcode
ensure_vals(globals(), 'rf_total')
@check_safety
def check():
    c_point0 = type(rf_total) == sklearn.model_selection._search.GridSearchCV
    c_point1 = hasattr(rf_total, 'fit') and hasattr(rf_total, 'predict')

    if c_point0 and c_point1  :
        return True
    else:
        return False

check()

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
#
# empty

# %% [markdown]
# ### Solution.
#
# ```python
# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
#
# params = {'n_estimators' : [100, 150, 200],
#           'criterion' : ['gini', 'entropy']}
#
# rf_total = GridSearchCV(RandomForestClassifier(random_state=42), param_grid=params, cv=2, return_train_score=True, verbose=3)
#
# rf_total.fit(X,y)
# ```

# %% [markdown]
# # 6.최적 성능 & 하이퍼파라미터 출력
#
# [문제 6]
# 1. GridSearchCV를 통해 찾은 최적 모델의 평가 점수를 확인해 보세요.
# 2. GridSearchCV를 통해 찾은 최적 모델의 하이퍼파라미터 조합을 확인해 보세요.

# %%
total_score = ___
total_params = ___

print("최적 성능 : ",total_score)
print("최적 하이퍼파라미터 : ",total_params)
# Out:
# {'criterion': 'entropy', 'n_estimators': 200}

# %%
#checkcode
ensure_vals(globals())
@check_safety
def check(
    user_score=total_score,
    user_params=total_params, 
    user_answer=rf_total
    ):

    c_point0 = user_score == user_answer.best_score_
    c_point1 = user_params == user_answer.best_params_

    if c_point0 and c_point1:
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# 1.best_score_
# 2.best_params

# %% [markdown]
# ### Solution.
#
# ```python
# total_score = rf_total.best_score_
# total_params = rf_total.best_params_
#
# print("최적 성능 : ",total_score)
# print("최적 하이퍼파라미터 : ",total_params)
# ```

# %% [markdown]
# # 7.앙상블에 활용될 RandomForest, GradientBoosting, ExtraTrees 분류기 모델
#
# 앙상블 모델을 학습하기 전에 개별 모델들을 최적화하기 위해, 다음과 같은 모델들을 선언합니다.
#
# 이번 최적화 과정을 통해 개별 모델들의 성능을 향상시키고, 앙상블 모델의 예측력을 향상시킬 것입니다.
# 각 개별 모델은 독립적으로 최적화되며, 최적의 하이퍼파라미터 조합을 찾기 위해 적절한 탐색 알고리즘을 활용할 수 있습니다.
#
# 앙상블 모델은 개별 모델들의 예측 결과를 종합하여 더 정확한 예측을 도출합니다.
# 따라서, 개별 모델들을 최적화하여 각 모델의 예측력을 극대화하는 것이 앙상블 모델의 성능 향상에 중요한 역할을 합니다.
#
# 최적화된 개별 모델들을 활용하여 앙상블 모델을 학습하게 되면, 개별 모델들의 다양한 예측 능력을 결합하여 보다 강력한 예측 모델을 구축할 수 있습니다.
#
# [문제 7]
#
# 1. RandomForestClassifier 모델 객체를 rfc 변수에 할당해 보세요.
# random_state=42를 통해 재현성을 보장시켜주세요. 이후 models 리스트에 추가됩니다.
# 2. GradientBoostingClassifier 모델 객체를 gbc 변수에 할당해 보세요.
# 3. ExtraTreesClassifier 모델 객체를 etc 변수에 할당해 보세요.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

models = []

rfc = ___(___=42)
models.append(rfc)

gbc = ___(random_state=42)
models.append(gbc)

etc = ___(random_state=42)
models.append(etc)

# %%
#checkcode
ensure_vals(globals(), 'models')
@check_safety
def check(
    user_answer=models, 
    user_number=2,
    user_model="<class 'sklearn.ensemble._forest.ExtraTreesClassifier'>" 
    ):

    c_point1 = str(type(user_answer[user_number])) == user_model
    
    if c_point1:
        return True
    else:
        return False
check()

# %% [markdown]
# ### Inst.
#
# 1. RandomForestClassifier는 무작위로 선택된 결정 트리들의 앙상블로 구성된 분류기입니다.
#
# 2. GradientBoostingClassifier는 경사 하강법을 이용한 부스팅(Boosting) 알고리즘을 기반으로 한 분류기입니다.
#
# 3. ExtraTreesClassifier는 무작위로 선택된 결정 트리들의 앙상블로 구성된 분류기입니다.
#
# 따라서, 해당 코드는 앙상블에 활용될 RandomForestClassifier, GradientBoostingClassifier,
# ExtraTreesClassifier 모델을 정의하고, 이를 models 리스트에 추가하는 역할을 합니다.
# 이렇게 모델을 리스트에 추가함으로써 앙상블 모델을 구성할 수 있습니다.

# %% [markdown]
# ### Hint.
#
# empty

# %% [markdown]
# ### Solution.
# ```python
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.ensemble import ExtraTreesClassifier
#
# models = []
#
# rfc = RandomForestClassifier(random_state=42)
# models.append(rfc)
#
# gbc = GradientBoostingClassifier(random_state=42)
# models.append(gbc)
#
# etc = ExtraTreesClassifier(random_state=42)
# models.append(etc)
# ```

# %% [markdown]
# # 8.앙상블 모델 파라미터 최적화를 위한 GridSearchCV 설정
#
# [문제 8]
#
# 1. 파라미터들을 저장할 params 리스트를 생성해 주세요.
#
# 2. RandomForestClassifier 모델의 최적화할 파라미터로서 n_estimators 값을 [100, 120, 140]으로 설정하여 params_rfc에 저장해주세요.
#
# 3. 이를 append 함수를 사용하여 params 리스트에 추가해 주세요.

# %%
params = ___ # 모델들의 파라미터들을 할당할 리스트를 만들어 줍니다

params_rfc = {'___' : [___]} # params 리스트에 성능을 비교하고자 하는 파라미터들을 선언합니다
params.___(___) # 파라미터들을 리스트에 저장합니다

params_gbc = {'learning_rate':[0.05,0.1,0.15],
             'n_estimators':[60,100,140]}
params.append(params_gbc)

params_etc = {'n_estimators' : [50,100,150]}
params.append(params_etc)
# Out:
# Fitting 4 folds for each of 3 candidates, totalling 12 fits
# [CV] END ...................................n_estimators=100; total time=   1.0s
# [CV] END ...................................n_estimators=100; total time=   1.0s
# [CV] END ...................................n_estimators=100; total time=   1.4s
# [CV] END ...................................n_estimators=100; total time=   1.4s
# [CV] END ...................................n_estimators=120; total time=   1.4s
# [CV] END ...................................n_estimators=120; total time=   1.1s
# [CV] END ...................................n_estimators=120; total time=   1.1s
# [CV] END ...................................n_estimators=120; total time=   1.1s
# [CV] END ...................................n_estimators=140; total time=   1.3s
# [CV] END ...................................n_estimators=140; total time=   1.3s
# [CV] END ...................................n_estimators=140; total time=   2.5s
# ...

# %%
#checkcode
ensure_vals(globals(), 'params')
@check_safety
def check(
    user_answer=params, 
    user_parmas={'n_estimators': [50, 100, 150]},
    user_number=2
    ):

    c_point1 = user_answer[user_number] == user_parmas
    
    if c_point1:
        return True
    else:
        return False
check()

# %% [markdown]
# ### Inst.
#
# 앙상블 모델을 구성하는 각각의 모델에 대해 최적의 파라미터를 찾기 위한 그리드 서치를 설정하는 코드입니다.
#
# 1. params: 모델들의 파라미터를 할당하기 위한 빈 리스트입니다.
# 2. params_rfc: RandomForestClassifier 모델의 성능을 비교하고자 하는 파라미터인 'n_estimators'를 선언합니다.
# 3. params_gbc: GradientBoostingClassifier 모델의 성능을 비교하고자 하는 파라미터인 'learning_rate'와 'n_estimators'를 선언합니다.
# 4. params_etc: ExtraTreesClassifier 모델의 성능을 비교하고자 하는 파라미터인 'n_estimators'를 선언합니다.
#
# 각각의 파라미터들은 리스트로 지정되어 있으며,
# 그리드 서치를 수행할 때 이 파라미터들의 조합을 모두 탐색하여 최적의 조합을 찾습니다.
# 파라미터들은 params 리스트에 순서대로 추가되어 저장됩니다.
# 이후 GridSearchCV를 사용하여 모델과 파라미터 그리드를 설정하고, 모델을 학습하면서 최적의 파라미터를 찾습니다.

# %% [markdown]
# ### Hint.
#
# empty

# %% [markdown]
# ### Solution.
# ```python
# params = [] # 모델들의 파라미터들을 할당할 리스트를 만들어 줍니다
#
# params_rfc = {'n_estimators' : [100, 120,140]} # params 리스트에 성능을 비교하고자 하는 파라미터들을 선언합니다
# params.append(params_rfc) # 파라미터들을 리스트에 저장합니다
#
# params_gbc = {'learning_rate':[0.05,0.1,0.15],
#              'n_estimators':[60,100,140]}
# params.append(params_gbc)
#
# params_etc = {'n_estimators' : [50,100,150]}
# params.append(params_etc)
# ```

# %% [markdown]
# # 9. 앙상블 모델의 파라미터 최적화를 통한 모델 선택
#
# [문제 9]
#
# 1. 빈 딕셔너리 best_models를 생성합니다.
#
# 2. models 리스트에 있는 각 모델에 대해 반복합니다.
#
# 3. GridSearchCV를 사용하여 해당 모델에 대한 파라미터 그리드 서치를 수행합니다.
# param_grid에는 해당 모델의 파라미터 후보들이 들어있는 params 리스트의 요소를 전달합니다.
#
# 4. 모델을 주어진 데이터 X와 y에 대해 학습시킵니다.
#
# 5. model.best_estimator_를 사용하여 최적의 파라미터로 훈련된 모델을 얻습니다.
# best_models 딕셔너리에 해당 모델의 인덱스 i를 키로 사용하여 최적 모델을 저장합니다.

# %%
best_models={}

for i, model in enumerate(___):
    model = ___(model, ___=params[i], cv=2, return_train_score=True, verbose=3)

    model.___(___,___)

    best_models[i] = model.___

# %%
#checkcode
ensure_vals(globals(), 'best_models')
@check_safety
def check(
    user_answer=best_models, 
    user_number=2,
    user_model="<class 'sklearn.ensemble._forest.ExtraTreesClassifier'>" ):

    c_point1 = str(type(user_answer[user_number])) == user_model
    
    if c_point1:
        return True
    else:
        return False
check()

# %% [markdown]
# ### Inst.
#
# best_models라는 빈 딕셔너리를 초기화합니다.
# 이 딕셔너리는 그리드 서치를 통해 얻은 각 모델의 최적 모델을 저장할 때 사용됩니다.
#
# enumerate 함수를 사용하여 models 리스트의 각 모델과 해당 인덱스를 순회합니다.
# 모델마다 그리드 서치를 수행하고, 최적의 파라미터 조합을 찾습니다.
# 최적 모델은 model.best_estimator_를 통해 얻을 수 있으며, 이를 best_models 딕셔너리에 해당 모델의 인덱스를 키로 하여 저장합니다.
#
# 따라서, 위 코드는 앙상블에 활용될 각 모델의 파라미터를 그리드 서치를 통해 최적화하고,
# 그 결과를 best_models 딕셔너리에 저장하는 과정을 보여줍니다.
# 이를 통해 각 모델의 최적 파라미터로 구성된 앙상블 모델을 구성할 수 있게 됩니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# best_models={}
#
# for i, model in enumerate(models):
#     model = GridSearchCV(model, param_grid=params[i], cv=2, return_train_score=True, verbose=3)
#
#     model.fit(X,y)
#
#     best_models[i] = model.best_estimator_
# ```

# %% [markdown]
# # 10.각 모델의 최적 파라미터

# %%
best_models
# Out:
# {0: RandomForestClassifier(n_estimators=140, random_state=42),
#  1: GradientBoostingClassifier(learning_rate=0.15, n_estimators=140,
#                             random_state=42),
#  2: ExtraTreesClassifier(random_state=42)}

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
#
# best_models는 각 모델에 대해 수행한 파라미터 GridSearchCV 를 통해 얻은 최적의 모델들을 저장하는 딕셔너리입니다.
#
# 이 딕셔너리는 다음과 같이 구성됩니다:
#
# - 키(key): 모델의 인덱스(i 값)
# - 값(value): 해당 모델에 대한 최적의 모델 객체
#
# 따라서 best_models를 출력하면 각 모델에 대한 최적의 모델이 저장된 딕셔너리가 출력됩니다.
# 이를 통해 각 모델의 최적의 파라미터로 훈련된 모델 객체를 확인할 수 있습니다.

# %% [markdown]
# ### Hint.
#
# empty

# %% [markdown]
# ### Solution.
#
# empty

# %% [markdown]
# # 11.Hard Voting Classifier
#
# 이제 실제로 test 데이터 세트를 사용하여 예측값을 생성해 보겠습니다.
# 각 fold(폴드)별로 최적의 모델을 사용하여 커스텀 보팅(Voting)을 수행해 보겠습니다.
# 보팅은 일반적으로 Hard Voting Classifier와 Soft Voting Classifier로 구분됩니다.
#
# [문제 10]
#
# 1. best_models의 첫 번째 모델을 사용하여 test 데이터셋의 특성 features를 기반으로 예측을 수행해 보세요.
# 2. best_models의 두 번째 모델을 사용하여 test 데이터셋의 특성 features를 기반으로 예측을 수행해 보세요.
# 3. best_models의 세 번째 모델을 사용하여 test 데이터셋의 특성 features를 기반으로 예측을 수행해 보세요.
# 4. 예측된 결과인 pred0, pred1, pred2를 이용하여 데이터프레임 pred를 생성해 보세요.

# %%
pred0 = best_models[___].predict(___[___])
pred1 = best_models[___].___(___[___])
pred2 = ___[___].___(___[___])

pred = pd.___({'pred0':___, 'pred1':___, 'pred2':___})
pred
# Out:
#      pred0  pred1  pred2
# 0        6      6      6
# 1        6      6      6
# 2        6      5      6
# 3        5      6      5
# 4        6      6      6
# ..     ...    ...    ...
# 995      6      5      6
# 996      6      6      6
# 997      5      5      5
# 998      6      6      6
# 999      6      6      6
#
# [1000 rows x 3 columns]

# %%
#checkcode
ensure_vals(globals())
@check_safety
def check(user_answer=_, number=(1000, 3)):

    c_point1 = user_answer.shape == number
    if c_point1:
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# 1. best_models[i]
# 2. pd.DataFrame

# %% [markdown]
# ### Solution.
# ```python
# pred0 = best_models[0].predict(test[features])
# pred1 = best_models[1].predict(test[features])
# pred2 = best_models[2].predict(test[features])
#
# pred = pd.DataFrame({'pred0':pred0, 'pred1':pred1, 'pred2':pred2})
# pred
# ```

# %% [markdown]
# # 12.mode 메소드를 이용한 Hard Voting
#
# [문제 11]
# pred의 각 행(row)에 대해 최빈값을 계산해 보세요.
# 구한 최빈값을 정수형으로 변환해 주세요.

# %%
pred['pred'] = pred.___(___=___)[0].___(___)
pred['pred']
# Out:
# 0      6
# 1      6
# 2      6
# 3      5
# 4      6
#       ..
# 995    6
# 996    6
# 997    5
# 998    6
# 999    6
# Name: pred, Length: 1000, dtype: int64

# %%
#checkcode
ensure_vals(globals())
@check_safety
def check(user_answer=_, number=(1000,)):

    c_point1 = user_answer.shape == number
    if c_point1:
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# 1. mode
# 2. axis
# 3. astype

# %% [markdown]
# ### Solution.
# ```python
# pred['pred'] = pred.mode(axis=1)[0].astype(int)
# pred['pred']
# ```

# %% [markdown]
# # 13.Soft Voting Classifier
#
# [문제 12]
# 앙상블에 사용되는 모든 분류기가 클래스의 확률을 예측할 수 있을 때 사용합니다.
# 각 분류기의 예측 확률을 평균 내어, 값이 가장 높은 클래스를 최종 예측값으로 정합니다.
#
#
# 1. best_models의 첫 번째 모델을 사용하여 test 데이터셋의 특성 features를 기반으로
# 각 클래스에 대한 예측 확률을 구해보세요.
# 2. best_models의 두 번째 모델을 사용하여 test 데이터셋의 특성 features를 기반으로
# 각 클래스에 대한 예측 확률을 구해보세요.
# 3. pred0, pred1, pred2의 예측 확률을 더한 후 3으로 나누어 평균을 계산하고,
# 이를 데이터프레임으로 변환하여 pred에 저장해 보세요.

# %%
pred0 = best_models[___].___(___[___])
pred1 = best_models[1].predict_proba(test[features])
pred2 = best_models[2].predict_proba(test[features])

pred = pd.___((___ + ___ + ___)/___)
pred

# %%
#checkcode
ensure_vals(globals())
@check_safety
def check(user_answer=_, number=(1000, 7)):

    c_point1 = user_answer.shape == number
    if c_point1:
        return True
    else:
        return False
    
check()
# Out:
# False

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# 1. predict_proba()
# 2. pd.DataFrame()

# %% [markdown]
# ### Solution.
# ```python
# pred0 = best_models[0].predict_proba(test[features])
# pred1 = best_models[1].predict_proba(test[features])
# pred2 = best_models[2].predict_proba(test[features])
#
# pred = pd.DataFrame((pred0 + pred1 + pred2)/3)
# pred
# ```

# %% [markdown]
# # 14.Soft Voting 예측값 데이터프레임 생성
# [문제 13]
# argmax 함수를 이용하여 주어진 축을 따라 가장 큰 값의 인덱스를 반환해 보세요.
# 다만, 클래스는 0 ~ 6 의 수로 구성되어 있는데 학습 데이터에 분포한 클래스는 3 ~ 9 이므로, +3를 해 주겠습니다.

# %%
import numpy as np

pred = pd.DataFrame(np.array(pred).___(axis=___)+3)
pred
# Out:
#      0
# 0    6
# 1    6
# 2    6
# 3    5
# 4    6
# ..  ..
# 995  6
# 996  6
# 997  5
# 998  6
# 999  6
#
# [1000 rows x 1 columns]

# %%
#checkcode
ensure_vals(globals())
@check_safety
def check(user_answer=_,user_number=(1000,1)):

    c_point1 = user_answer.shape == user_number
    
    if c_point1:
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.

# %% [markdown]
# ### Hint.
# - argmax
# - axis = 1

# %% [markdown]
# ### Solution.
#
# ```python
# import numpy as np
#
# pred = pd.DataFrame(np.array(pred).argmax(axis=1)+3)
# pred
# ```

# %% [markdown]
# # 15.sklearn을 이용한 Hard Voting 앙상블 분류기의 학습
#
# 이번에는 sklearn 패키지의 VotingClassifier 메소드를 사용하여 하드 보팅 앙상블 모델을 구현해 보겠습니다.
#
# [문제 14]
#
# 1. 각각의 개별 모델과 그에 해당하는 이름을 튜플 형태로 estimators 리스트에 저장합니다.
# best_models[0] 의 이름을 rfc로 부여해 주세요.
#
# 2. VotingClassifier 모델을 선언해 보세요.
# estimators 인자에 앞서 생성한 estimators 리스트를 전달하고,
# voting 인자에는 앙상블 방식을 설정합니다. 여기서는 'hard' voting 방식을 선택해 주세요.
#
# 3. fit 함수를 통해 모델을 학습시킵니다.
# X는 입력 데이터, y는 해당하는 타겟 변수를 나타냅니다.

# %%
from sklearn.ensemble import VotingClassifier #앙상블 기법을 위한 패키지

estimators = [
    ('rfc', best_models[0]),
    ('gbc', best_models[1]),
    ('etc', best_models[2])
]

model = ___(estimators=___, voting='___') #앙상블 모델 선언
model.___(X, y) #모델 학습
# Out:
# VotingClassifier(estimators=[('rfc',
#                               RandomForestClassifier(n_estimators=140,
#                                                      random_state=42)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.15,
#                                                          n_estimators=140,
#                                                          random_state=42)),
#                              ('etc', ExtraTreesClassifier(random_state=42))])

# %%
#checkcode
ensure_vals(globals(), 'model')
@check_safety
def check(
    user_answer=model,
    user_instance='hard',
    user_model="<class 'sklearn.ensemble._voting.VotingClassifier'>"
    ):

    c_point1 = str(type(user_answer)) == user_model
    c_point2 = user_answer.voting == user_instance

    if c_point1 and c_point2:
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.
#
# sklearn의 VotingClassifier를 사용하여 앙상블 모델을 구현하는 코드입니다.
# VotingClassifier를 불러옵니다.
#
# estimators 리스트는 앙상블에 사용할 개별 모델들을 정의합니다.
# 각 튜플은 모델의 이름(식별자)과 실제 모델 객체로 구성됩니다.
# 예를 들어, ('rfc', best_models[0])는 이름이 'rfc'인 모델 best_models[0]를 의미합니다.
# 이와 같은 방식으로 원하는 모델들을 리스트에 추가합니다.
#
# model은 VotingClassifier 객체를 생성합니다.
# estimators를 전달하여 앙상블에 사용할 모델들을 설정하고,
# voting 매개변수를 'hard'로 설정하여 하드 보팅을 수행합니다.
#
# 마지막으로, model.fit(X, y)를 통해 앙상블 모델을 학습시킵니다.
# X는 학습 데이터, y는 해당 데이터의 타겟 변수(레이블)입니다.
# 이렇게 구성된 앙상블 모델은 각 개별 모델들의 예측을 종합하여 최종 예측을 수행합니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# from sklearn.ensemble import VotingClassifier #앙상블 기법을 위한 패키지를 불러옵니다.
#
# estimators = [
#     ('rfc', best_models[0]),
#     ('gbc', best_models[1]),
#     ('etc', best_models[2])
# ]
#
# model = VotingClassifier(estimators=estimators, voting='hard') #앙상블 모델을 선언합니다. 디폴트값 Hard Voting Classifier
# model.fit(X, y) #모델을 학습시킵니다
# ```

# %% [markdown]
# # 16.sklearn을 이용한 Soft Voting 앙상블 분류기의 학습
#
# [문제 15]
# 이번에는 sklearn 패키지의 VotingClassifier 메소드를 사용하여 소프트 보팅 앙상블 모델을 구현해 보겠습니다.
#
#
# 1. VotingClassifier 객체를 model 변수에 할당해 주세요.
# 2. estimators 인자에  estimators 리스트를 전달하고,
# 3. voting 매개변수를 설정하여 소프트 보팅을 수행해 보세요.
# 4. 앙상블 모델을 학습시켜 주세요.

# %%
from sklearn.ensemble import VotingClassifier 

estimators = [
    ('rfc', best_models[0]),
    ('gbc', best_models[1]),
    ('etc', best_models[2])
]

model = ___(estimators=___, voting='___') 
model.___(X, y)
# Out:
# 1.0

# %%
#checkcode
ensure_vals(globals(), 'model')
@check_safety
def check(
    user_answer=model,
    user_instance='soft',
    user_model="<class 'sklearn.ensemble._voting.VotingClassifier'>"
    ):

    c_point1 = str(type(user_answer)) == user_model
    c_point2 = user_answer.voting == user_instance

    if c_point1 and c_point2:
        return True
    else:
        return False
    
check()

# %% [markdown]
# ### Inst.
#
# model.score(X, y)를 사용하여 학습된 앙상블 모델의 정확도를 평가합니다.
# score 메소드는 주어진 입력 데이터 X와 해당 데이터의 타겟 변수 y에 대한 정확도를 계산합니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# ```python
# from sklearn.ensemble import VotingClassifier
#
# estimators = [
#     ('rfc', best_models[0]),
#     ('gbc', best_models[1]),
#     ('etc', best_models[2])
# ]
#
# model = VotingClassifier(estimators=estimators, voting='soft')
# model.fit(X, y)
# ```

# %% [markdown]
# # 17.submission 파일에 값 채우기
#
# [문제 16]
#
# 1. 앙상블 모델인 model을 사용하여 test[features]에 대한 예측을 수행한 결과를 반환해 보세요.
# 2. 예측 결과를 데이터프레임 형식으로 변환해 보세요.
# 3. 앙상블 모델의 예측 결과를 'quality' 열로 구성된 submission 데이터프레임에 저장해 보세요.

# %%
submission['quality'] = pd.___(model.predict(___[___]))
submission.head(10)

# %%
#checkcode
ensure_vals(globals(), 'pred')
@check_safety
def check(user_answer=_, number=(10,2)):

    c_point1 = user_answer.shape == number
    if c_point1:
        return True
    else:
        return False
    
check()
# Out:
# True

# %% [markdown]
# ### Inst.
# 모델링으로 예측한 값을 채워 봅시다.

# %% [markdown]
# ### Hint.
# submission 데이터 프레임의 quality열에 pd.DataFrame(model.predict(test[features]))을 대입해 보세요.

# %% [markdown]
# ### Solution.
# ```python
# submission['quality'] = pd.DataFrame(model.predict(test[features]))
# submission.head(10)
# ```

# %% [markdown]
# # 18.데이터프레임(DataFrame)을 CSV 파일로 저장하기
#
# submission.csv 파일로 저장해 보겠습니다.

# %%
submission.to_csv('submission.csv', index=False)

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
# 저장할 csv파일의 이름을 지정하기 위해 메서드에 문자열 submission.csv를 입력하였고,
# 인덱스를 csv 파일에 포함하지 않고 저장하기 위해 `index=False`를 사용했습니다.
# 따라서 인덱스를 제외한 데이터만 저장됩니다.

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# empty
